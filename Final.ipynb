# %%
from IPython.display import display
import pandas as pd
df=pd.read_csv('payloads.csv')
payload = df['payload'].values.tolist()
label = df['is_malicious'].values.tolist()
for i in range(0,len(label)):
    if(label[i]==0):
        label[i]=1
    elif(label[i]==1):
        label[i]==0

df=pd.read_csv('label.csv')
name = df['Queries'].values.tolist()
y = df['Labels'].values.tolist()
df1=df.loc[df['Labels'] == 0]
df2=df.loc[df['Labels'] == 1]
name0=df1['Queries'].values.tolist()
label0=df1['Labels'].values.tolist()
name1=df2['Queries'].values.tolist()
labelo=df2['Labels'].values.tolist()
for i in range(0,len(label)):
    if(label[i]==0):
        name0.append(payload[i])
        label0.append(label[i])
    elif(label[i]==1):
        name1.append(payload[i])
        labelo.append(label[i])
fn=[]
fl=[]
for i in range(0,len(name0)):
    fn.append(name0[i])
    fl.append(label0[i])
for i in range(0,len(name1)):
    fn.append(name1[i])
    fl.append(labelo[i])
df3=pd.DataFrame(fn, columns =['Queries'])
df3['Label']=fl
df3.to_csv('data.csv')

# %%
from IPython.display import display
import pandas as pd
df=pd.read_csv('label.csv')
display(df.head(30))
# Out:
#                                               Queries  Labels
# 0                /top.php?stuff='uname >q36497765 #\n       0
# 1   /h21y8w52.nsf?<script>cross_site_scripting.nas...       0
# 2   /ca000001.pl?action=showcart&hop=\"><script>al...       0
# 3   /scripts/edit_image.php?dn=1&userfile=/etc/pas...       0
# 4                               /javascript/mta.exe\n       0
# 5   /examples/jsp/colors/kernel/loadkernel.php?ins...       0
# 6   /examples/jsp/cal/feedsplitter.php?format=../....       0
# 7   /phpwebfilemgr/index.php?f=../../../../../../....       0
# 8   /cgi-bin/script/cat_for_gen.php?ad=1&ad_direct...       0
# 9   /examples/jsp/cal/search.php?allwords=<br><scr...       0
# 10  /moodle/filter/tex/texed.php?formdata=foo&path...       0
# 11  /examples/jsp/colors/workarea/contentdesigner/...       0
# 12                      /id;1627282494;fp;2;fpid;1/\n       0
# 13  /<img src="javascript:alert(cross_site_scripti...       0
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn import linear_model, datasets
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import numpy as np
import pickle
df=pd.read_csv('data.csv')
name = df['Queries'].values.tolist()
y = df['Label'].values.tolist()
print(len(y))
x_train, x_test, y_train, y_test = train_test_split(name, y, test_size=0.2, random_state=1000)
vectorizer = CountVectorizer()
vectorizer.fit(x_train)
X_train = vectorizer.transform(x_train)
X_test  = vectorizer.transform(x_test)
classifier = linear_model.LogisticRegression(max_iter=10000)
classifier.fit(X_train, y_train)
score = classifier.score(X_test, y_test)
print("Accuracy:", score)
print(classification_report(y_test, classifier.predict(X_test)))
pkl_filename = "log_res.pkl"
with open(pkl_filename, 'wb') as file:
    pickle.dump(classifier, file)
# Out:
# 1158931
# Accuracy: 0.9893566075750582
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.86      9551
#            1       0.99      1.00      0.99    222236
#
#     accuracy                           0.99    231787
#    macro avg       0.95      0.91      0.93    231787
# weighted avg       0.99      0.99      0.99    231787

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn import linear_model, datasets
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import numpy as np
import pickle
with open(pkl_filename, 'rb') as file:
    model = pickle.load(file)
    
# Calculate the accuracy score and predict target values
#score = pickle_model.score(Xtest, Ytest)
#print("Test score: {0:.2f} %".format(100 * score))
#Ypredict = pickle_model.predict(Xtest)
#df=pd.read_csv('Sample_1.csv') #change file name
#test=df['name'].values.tolist()
#vectorizer.fit(test)
test=[]
code="SQL attack?"
test.append(code)
Test=vectorizer.transform(test)
R=model.predict(Test)
print(R)
df['Label']=R
df.to_csv("output.csv",index=False,header=True)
# Out:
# [1]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-7fafd9a51905> in <module>
#      25 R=model.predict(Test)
#      26 print(R)
# ---> 27 df['Label']=R
#      28 df.to_csv("output.csv",index=False,header=True)
#
# c:\users\amart\desktop\programs\python37\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# c:\users\amart\desktop\programs\python37\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ...
